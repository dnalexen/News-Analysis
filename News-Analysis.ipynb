# %% [markdown]
# # Challenge- News Analysis
#
# ![](https://static01.nyt.com/newsgraphics/images/icons/defaultPromoCrop.png)
#
# Picture from [The New York Times](www.nytimes.com)

# %% [markdown]
# ---

# %%
import spacy
from spacy import displacy

from collections import Counter

from bs4 import BeautifulSoup
import requests
import re

# TODO : load statistical models

# %% [markdown]
# # 1. Create a scrapper

# %% [markdown]
# We are going to scrape the following webpages :
# - https://www.nytimes.com/2019/08/06/upshot/china-us-trade-war-currency-markets.html
# - https://www.lesechos.fr/economie-france/social/deliveroo-dans-le-collimateur-de-la-justice-espagnole-1122616
#
# Write a function `url_to_string(url)` that returns the text content of the given webpage.

# %%
def url_to_string(url):
    response = requests.get(url)
    if response.status_code == 200:
        soup = BeautifulSoup(response.text)
        text = [paragraph.text for paragraph in soup.find_all('p')]
    return text

# %%
# save urls in variables
url_nyt = 'https://www.nytimes.com/2019/08/06/upshot/china-us-trade-war-currency-markets.html'
url_echos = 'https://www.lesechos.fr/economie-france/social/deliveroo-dans-le-collimateur-de-la-justice-espagnole-1122616'

# %%
# test the function url_to_string
text_nyt = url_to_string(url_nyt)
text_echos = url_to_string(url_echos)

# %%
text_nyt
# Out:
# ['Advertisement',
#  'Supported by',
#  'A trade war spills into the realm of currency, with no end in sight.',
#  'By Neil Irwin',
#  'To most people, Aug. 9, 2007, was an ordinary enough summer day. The stock market fell about 3 percent, sufficiently notable to lead the major newspapers, but hardly anything that would generate panic in the streets.',
#  'Yet to many people who work in economic policy or financial markets, that day was the beginning of what would eventually be called the global financial crisis. It was the day that lending froze up among banks within Europe, triggered by the breakdown in the market for bonds backed by American home mortgages, and central banks first intervened to try to keep money flowing.',
#  'Monday felt eerily similar, and not just because it was another August day in which the stock market fell by nearly identical amounts: The drop in the S&P 500 was 2.96 percent in 2007 and 2.98 percent Monday.',
#  'For months, people who study economic diplomacy between the United States and China have warned that the world’s two biggest economies are on a collision course, that the trade war between the two will have no easy resolution, and that this tension could spill into other areas of policy and create dangerous ripple effects for the world economy.',
#  'In the last several days, that pessimistic story has become more real.',
#  'On Thursday, President Trump said he would place 10 percent tariffs on $300 billion in Chinese goods, ending a period in which there seemed to be some easing of tensions between the two nations. On Monday, the Chinese government allowed its currency to fall below a symbolically important seven-to-the-dollar level, an apparent retaliatory move that amounts to trade tensions spreading into another arena. The United States returned fire by formally naming China a currency manipulator.',
#  'The swings in financial markets Monday are hard to justify in narrow terms. A slightly cheaper Chinese currency shouldn’t have huge consequences for the global economy. Rather, investors are coming to grips with the reality that the trade war is escalating and spreading into the global currency market.',
#  'While the drop in the stock market gets the attention — the S&P is down 5.8 percent in the last week — it is global bond markets that are flashing the most worrying signs about the outlook for growth in the United States and much of the world. Ten-year Treasury bonds yielded 1.72 percent at Monday’s close, down from 2.06 percent a week earlier — a sign that investors now believe that weaker growth and additional interest rate cuts by the Federal Reserve are on the way.',
#  '“The Chinese have sent a strong signal that they are ready to rumble,” said Paul Blustein, a senior fellow at the Centre for International Governance Innovation and the author of “Schism,” a book due out next month about the fraying relationship between the United States and China. “To depreciate the currency at such a fraught time sends a signal that they are prepared to endure a heck of a lot of pain, and it doesn’t surprise me that markets would finally come around and say, ‘This could be really bad.’”',
#  'As we’ve seen many times through this trade war, escalation and de-escalation can come at seemingly any time. President Trump could back away from his latest tariff threat and calm things down, or move the opposite direction by increasing the tariff to be charged on those $300 billion in imports from China. But one recurring theme of the last two years is that trade conflicts in the Trump era never seem to become fully resolved, but rather go through more-intense versus less-intense phases.',
#  'Whatever happens next — and whether this turns out to be the beginning of a major turning point for the global economy or just one rough day on the markets — it is clear that the trade war is no longer confined to trade.',
#  'While President Trump has often accused China of seizing advantage in global trade by manipulating the value of its currency to keep it lower, the latest developments reflect pretty much the opposite. In fact, a slowing Chinese economy is creating downward pressure on the renminbi — a pressure that China’s government has resisted, through intervention by its central bank and capital controls, to try to keep Chinese citizens from moving money out of the country.',
#  'On Monday, the Chinese essentially reduced the scale of that intervention and let the value of the yuan fall closer to the level it would reach in an open market.',
#  'The risk is that President Trump and eventually leaders of other nations will conclude that currencies are now fair game — that they are a good and appropriate weapon to use in trade disputes. For weeks Mr. Trump has pilloried the Federal Reserve for not cutting interest rates more, arguing that this has made the value of the dollar excessively high, weakening American exporters.',
#  'Trade disputes and currency disputes have historically gone hand in hand. Most notoriously, during the Great Depression nations competed to devalue their currencies in “beggar-thy-neighbor” policies that ultimately made everyone poorer. It’s less clear what a 21st-century currency war would look like.',
#  'Major nations have mostly agreed not to take action to artificially depress their currencies at the expense of their trading partners. But setting monetary and fiscal policies aimed at helping your domestic economy is considered O.K., even if doing so has implications for currencies. The thing is, it can be debatable which bucket a given policy fits into. For example, countries including Germany, China and Brazil accused the United States of manipulating its currency when the Fed engaged in “quantitative easing” policies in 2010 that depressed the value of the dollar.',
#  'If Mr. Trump directs his administration to try to drive the value of the dollar lower using Treasury Department authorities to intervene in markets, or prevails upon the Fed to more aggressively lower interest rates in order to depress the value of the dollar, that could embolden not just China but other economic powers, like Japan, South Korea and Europe, to do the same.',
#  'The entire structure of international institutions meant to prevent Depression-era policies would be under threat. In that situation, no nation would be able to achieve lasting economic advantage, but a set of financial institutions that have served the world well could be undermined.',
#  '“If you don’t change the economic fundamentals, intervening in currency markets won’t be effective,” said David Dollar, a senior fellow at the Brookings Institution and a former Treasury Department representative in China. Citing organizations like the World Trade Organization, he said, “The question for me is, does this end up damaging the core economic institutions?”',
#  'Nothing about the world economy over the last few years has been linear or predictable. There is no reason that the events of Aug. 5, 2019, need to be the first chapter of future books about the Global Recession of 2020. But to avoid that result, it matters that world leaders understand just what is at stake — and the pervasive pessimism in markets Monday was a good indication.',
#  'Advertisement']

# %%
text_echos
# Out:
# ['Deux jugements récents rendus à Valence et à Madrid reconnaissent les livreurs à vélo comme salariés de la plate-forme et lui réclament les cotisations sociales impayées.',
#  "Les livreurs à vélos de Deliveroo sont bien des salariés et non pas des travailleurs indépendants. C'est ce qu'a décidé la justice espagnole qui a condamné la plate-forme britannique pour fraude à la Sécurité sociale à deux reprises en l'espace de quelques semaines. Alertés par l'Inspection du travail, des tribunaux régionaux avaient en effet été appelés à se prononcer dans le cadre de deux affaires distinctes sur le statut des cyclistes de l'entreprise de livraison de repas à domicile.",
#  "Un premier jugement, rendu à Valence en juin, avait tranché en faveur de l'administration qui dénonçait le cas de 97 coursiers déclarés frauduleusement comme «\xa0autonomos\xa0», équivalent espagnol du statut d'autoentrepreneur, et réclamait les cotisations sociales impayées par Deliveroo. A Madrid, un mois plus tard, la justice émettait un jugement similaire concernant le cas de 532 livreurs et condamnait là aussi la plate-forme, exigeant le paiement de 1,2\xa0million d'euros de cotisations. Deliveroo devrait aller en appel, en attendant d'autres jugements sur des cas semblables qui devraient être rendus dans les prochains mois, à Barcelone et à Saragosse.",
#  "A Valence et à Madrid, les deux décisions de justice ont clairement convergé en considérant que le faux statut d'«\xa0autonomo\xa0» imposé aux coursiers avait permis à l'entreprise de faire l'économie du paiement des cotisations sociales. Alors que Deliveroo présente les cyclistes comme indépendants, libres de leurs horaires et disposant de leurs propres outils de travail, le tribunal de Valence établit que «\xa0les vrais moyens de production ne sont pas le vélo ou le téléphone portable utilisés par le rider, mais la plate-forme digitale permettant de connecter l'offre et la demande, propriété de l'entreprise\xa0». La liberté horaire est par ailleurs relative selon le tribunal puisque les algorithmes peuvent favoriser ou sanctionner un livreur plus ou moins efficace.",
#  "Selon les magistrats de Madrid, «\xa0une fois la commande acceptée\xa0», le coursier doit «\xa0l'honorer en suivant les instructions détaillées déterminées par l'entreprise, sans marge appréciable d'autonomie\xa0». Le jugement donne pour preuve le modus operandi de la plate-forme qui fait accompagner les livreurs novices lors de leur première tournée par des coursiers plus expérimentés pour leur «\xa0enseigner la mécanique du service\xa0».",
#  "Ces sentences ont eu lieu peu de temps après la mort, à Barcelone, d'un livreur à vélo de l'entreprise Glovo, qui opère dans les conditions comparables à celles de Deliveroo. Son décès en mai dernier dans un accident de la circulation, avait attiré l'attention de l'opinion publique sur la précarité du travail des coursiers. Il avait permis de mettre à jour la façon dont Glovo, comme Deliveroo et les autres plates-formes, sont utilisées depuis des années par des migrants sans papiers pour pouvoir décrocher quelques heures de travail, et comment les cyclistes sont poussés à accélérer la cadence et à prendre des risques lors de leurs déplacements, mis sous pression par les systèmes de notation des clients et des algorithmes, afin d'avoir plus de travail et aux heures les plus rentables.",
#  'Cécile Thibaud\xa0 (Correspondante à Madrid)',
#  'Chaque jour, la rédaction des Echos répond à votre besoin d’une information fiable et vous aide à prendre les meilleures décisions.',
#  'Conservez une vision globale de la situation, en France et dans le monde. Décryptez les conséquences de la crise sur l’économie, les entreprises et les marchés. Eclairez votre réflexion avec des points de vue, des idées et des contributions de tous horizons.',
#  'Reprenez un temps d’avance avec Les Echos. Abonnez-vous dès maintenant !',
#  '',
#  '',
#  'Tous droits réservés\xa0-\xa0Les Echos 2020']

# %% [markdown]
# # 2. Analyse English News with NER

# %%
#Create the nlp object -- this object will parse the text and preprocess it automatically
nlp_en = spacy.load("en_core_web_md")

# %%
# parse the document with spacy.load
nyt_doc = [nlp_en(paragraph) for paragraph in text_nyt]

# %%
nyt_doc
# Out:
# [Advertisement,
#  Supported by,
#  A trade war spills into the realm of currency, with no end in sight.,
#  By Neil Irwin,
#  To most people, Aug. 9, 2007, was an ordinary enough summer day. The stock market fell about 3 percent, sufficiently notable to lead the major newspapers, but hardly anything that would generate panic in the streets.,
#  Yet to many people who work in economic policy or financial markets, that day was the beginning of what would eventually be called the global financial crisis. It was the day that lending froze up among banks within Europe, triggered by the breakdown in the market for bonds backed by American home mortgages, and central banks first intervened to try to keep money flowing.,
#  Monday felt eerily similar, and not just because it was another August day in which the stock market fell by nearly identical amounts: The drop in the S&P 500 was 2.96 percent in 2007 and 2.98 percent Monday.,
#  For months, people who study economic diplomacy between the United States and China have warned that the world’s two biggest economies are on a collision course, that the trade war between the two will have no easy resolution, and that this tension could spill into other areas of policy and create dangerous ripple effects for the world economy.,
#  In the last several days, that pessimistic story has become more real.,
#  On Thursday, President Trump said he would place 10 percent tariffs on $300 billion in Chinese goods, ending a period in which there seemed to be some easing of tensions between the two nations. On Monday, the Chinese government allowed its currency to fall below a symbolically important seven-to-the-dollar level, an apparent retaliatory move that amounts to trade tensions spreading into another arena. The United States returned fire by formally naming China a currency manipulator.,
#  The swings in financial markets Monday are hard to justify in narrow terms. A slightly cheaper Chinese currency shouldn’t have huge consequences for the global economy. Rather, investors are coming to grips with the reality that the trade war is escalating and spreading into the global currency market.,
#  While the drop in the stock market gets the attention — the S&P is down 5.8 percent in the last week — it is global bond markets that are flashing the most worrying signs about the outlook for growth in the United States and much of the world. Ten-year Treasury bonds yielded 1.72 percent at Monday’s close, down from 2.06 percent a week earlier — a sign that investors now believe that weaker growth and additional interest rate cuts by the Federal Reserve are on the way.,
#  “The Chinese have sent a strong signal that they are ready to rumble,” said Paul Blustein, a senior fellow at the Centre for International Governance Innovation and the author of “Schism,” a book due out next month about the fraying relationship between the United States and China. “To depreciate the currency at such a fraught time sends a signal that they are prepared to endure a heck of a lot of pain, and it doesn’t surprise me that markets would finally come around and say, ‘This could be really bad.’”,
#  As we’ve seen many times through this trade war, escalation and de-escalation can come at seemingly any time. President Trump could back away from his latest tariff threat and calm things down, or move the opposite direction by increasing the tariff to be charged on those $300 billion in imports from China. But one recurring theme of the last two years is that trade conflicts in the Trump era never seem to become fully resolved, but rather go through more-intense versus less-intense phases.,
#  Whatever happens next — and whether this turns out to be the beginning of a major turning point for the global economy or just one rough day on the markets — it is clear that the trade war is no longer confined to trade.,
#  While President Trump has often accused China of seizing advantage in global trade by manipulating the value of its currency to keep it lower, the latest developments reflect pretty much the opposite. In fact, a slowing Chinese economy is creating downward pressure on the renminbi — a pressure that China’s government has resisted, through intervention by its central bank and capital controls, to try to keep Chinese citizens from moving money out of the country.,
#  On Monday, the Chinese essentially reduced the scale of that intervention and let the value of the yuan fall closer to the level it would reach in an open market.,
#  The risk is that President Trump and eventually leaders of other nations will conclude that currencies are now fair game — that they are a good and appropriate weapon to use in trade disputes. For weeks Mr. Trump has pilloried the Federal Reserve for not cutting interest rates more, arguing that this has made the value of the dollar excessively high, weakening American exporters.,
#  Trade disputes and currency disputes have historically gone hand in hand. Most notoriously, during the Great Depression nations competed to devalue their currencies in “beggar-thy-neighbor” policies that ultimately made everyone poorer. It’s less clear what a 21st-century currency war would look like.,
#  Major nations have mostly agreed not to take action to artificially depress their currencies at the expense of their trading partners. But setting monetary and fiscal policies aimed at helping your domestic economy is considered O.K., even if doing so has implications for currencies. The thing is, it can be debatable which bucket a given policy fits into. For example, countries including Germany, China and Brazil accused the United States of manipulating its currency when the Fed engaged in “quantitative easing” policies in 2010 that depressed the value of the dollar.,
#  If Mr. Trump directs his administration to try to drive the value of the dollar lower using Treasury Department authorities to intervene in markets, or prevails upon the Fed to more aggressively lower interest rates in order to depress the value of the dollar, that could embolden not just China but other economic powers, like Japan, South Korea and Europe, to do the same.,
#  The entire structure of international institutions meant to prevent Depression-era policies would be under threat. In that situation, no nation would be able to achieve lasting economic advantage, but a set of financial institutions that have served the world well could be undermined.,
#  “If you don’t change the economic fundamentals, intervening in currency markets won’t be effective,” said David Dollar, a senior fellow at the Brookings Institution and a former Treasury Department representative in China. Citing organizations like the World Trade Organization, he said, “The question for me is, does this end up damaging the core economic institutions?”,
#  Nothing about the world economy over the last few years has been linear or predictable. There is no reason that the events of Aug. 5, 2019, need to be the first chapter of future books about the Global Recession of 2020. But to avoid that result, it matters that world leaders understand just what is at stake — and the pervasive pessimism in markets Monday was a good indication.,
#  Advertisement]

# %%
# TODO: load entities
for paragraph in nyt_doc:
    spacy.displacy.render(paragraph, style="ent")
    print('                                              -------------                                          ')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Advertisement</div></span>
#                                               -------------
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Supported by</div></span>
#                                               -------------
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">A trade war spills into the realm of currency, with no end in sight.</div></span>
#                                               -------------
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">By
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Neil Irwin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </div></span>
#                                               -------------
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">To most people,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Aug. 9, 2007
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , was an ordinary enough
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     summer day
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . The stock market fell
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     about 3 percent
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
# , sufficiently notable to lead the major newspapers, but hardly anything that would generate panic in the streets.</div></span>
#                                               -------------
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Yet to many people who work in economic policy or financial markets,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     that day
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  was the beginning of what would eventually be called the global financial crisis. It was
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the day
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  that lending froze up among banks within
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Europe
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# , triggered by the breakdown in the market for bonds backed by
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     American
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  home mortgages, and central banks first intervened to try to keep money flowing.</div></span>
#                                               -------------
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Monday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  felt eerily similar, and not just because it was
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     another August day
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  in which the stock market fell by nearly identical amounts: The drop in the S&amp;P 500 was
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2.96 percent
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2007
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  and
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2.98 percent
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Monday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .</div></span>
#                                               -------------
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">For
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     months
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , people who study economic diplomacy between
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the United States
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  and
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     China
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  have warned that the world’s
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     two
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  biggest economies are on a collision course, that the trade war between the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     two
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  will have no easy resolution, and that this tension could spill into other areas of policy and create dangerous ripple effects for the world economy.</div></span>
#                                               -------------
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">In
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the last several days
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , that pessimistic story has become more real.</div></span>
#                                               -------------
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">On
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Thursday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , President
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Trump
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  said he would place
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     10 percent
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  tariffs on
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $300 billion
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  in
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Chinese
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  goods, ending a period in which there seemed to be some easing of tensions between the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     two
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  nations. On
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Monday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , the
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Chinese
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  government allowed its currency to fall below a symbolically important
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     seven
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# -to-the-dollar level, an apparent retaliatory move that amounts to trade tensions spreading into another arena.
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The United States
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  returned fire by formally naming
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     China
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  a currency manipulator.</div></span>
#                                               -------------
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">The swings in financial markets
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Monday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  are hard to justify in narrow terms. A slightly cheaper
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Chinese
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  currency shouldn’t have huge consequences for the global economy. Rather, investors are coming to grips with the reality that the trade war is escalating and spreading into the global currency market.</div></span>
#                                               -------------
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">While the drop in the stock market gets the attention — the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     S&amp;P
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is down
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     5.8 percent
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the last week
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  — it is global bond markets that are flashing the most worrying signs about the outlook for growth in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the United States
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  and much of the world.
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ten-year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Treasury
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  bonds yielded
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1.72 percent
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  at
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Monday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ’s close, down from
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2.06 percent
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     a week earlier
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  — a sign that investors now believe that weaker growth and additional interest rate cuts by
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Federal Reserve
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  are on the way.</div></span>
#                                               -------------
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">“The
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Chinese
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  have sent a strong signal that they are ready to rumble,” said
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Paul Blustein
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , a senior fellow at
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Centre for International Governance Innovation
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and the author of “Schism,” a book due out
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     next month
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  about the fraying relationship between
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the United States
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  and
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     China
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# . “To depreciate the currency at such a fraught time sends a signal that they are prepared to endure a heck of a lot of pain, and it doesn’t surprise me that markets would finally come around and say, ‘This could be really bad.’”</div></span>
#                                               -------------
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">As we’ve seen many times through this trade war, escalation and de-escalation can come at seemingly any time. President
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Trump
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  could back away from his latest tariff threat and calm things down, or move the opposite direction by increasing the tariff to be charged on those
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $300 billion
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  in imports from
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     China
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# . But
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  recurring theme of
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the last two years
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  is that trade conflicts in the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Trump
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  era never seem to become fully resolved, but rather go through more-intense versus less-intense phases.</div></span>
#                                               -------------
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Whatever happens next — and whether this turns out to be the beginning of a major turning point for the global economy or just
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  rough day on the markets — it is clear that the trade war is no longer confined to trade.</div></span>
#                                               -------------
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">While President
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Trump
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  has often accused
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     China
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  of seizing advantage in global trade by manipulating the value of its currency to keep it lower, the latest developments reflect pretty much the opposite. In fact, a slowing
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Chinese
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  economy is creating downward pressure on the renminbi — a pressure that
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     China
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ’s government has resisted, through intervention by its central bank and capital controls, to try to keep
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Chinese
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  citizens from moving money out of the country.</div></span>
#                                               -------------
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">On
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Monday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , the
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Chinese
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  essentially reduced the scale of that intervention and let the value of the yuan fall closer to the level it would reach in an open market.</div></span>
#                                               -------------
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">The risk is that President
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Trump
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  and eventually leaders of other nations will conclude that currencies are now fair game — that they are a good and appropriate weapon to use in trade disputes. For
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     weeks
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  Mr.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Trump
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  has pilloried
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Federal Reserve
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  for not cutting interest rates more, arguing that this has made the value of the dollar excessively high, weakening
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     American
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  exporters.</div></span>
#                                               -------------
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Trade disputes and currency disputes have historically gone hand in hand. Most notoriously, during
# <mark class="entity" style="background: #ffeb80; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Great Depression nations
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">EVENT</span>
# </mark>
#  competed to devalue their currencies in “beggar-thy-neighbor” policies that ultimately made everyone poorer. It’s less clear what a
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     21st-century
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  currency war would look like.</div></span>
#                                               -------------
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Major nations have mostly agreed not to take action to artificially depress their currencies at the expense of their trading partners. But setting monetary and fiscal policies aimed at helping your domestic economy is considered O.K., even if doing so has implications for currencies. The thing is, it can be debatable which bucket a given policy fits into. For example, countries including
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Germany
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     China
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  and
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Brazil
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  accused
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the United States
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  of manipulating its currency when the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Fed
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  engaged in “quantitative easing” policies in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2010
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  that depressed the value of the dollar.</div></span>
#                                               -------------
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">If Mr.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Trump
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  directs his administration to try to drive the value of the dollar lower using
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Treasury Department
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  authorities to intervene in markets, or prevails upon the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Fed
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  to more aggressively lower interest rates in order to depress the value of the dollar, that could embolden not just
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     China
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  but other economic powers, like
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Japan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     South Korea
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  and
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Europe
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# , to do the same.</div></span>
#                                               -------------
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">The entire structure of international institutions meant to prevent
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Depression-era
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  policies would be under threat. In that situation, no nation would be able to achieve lasting economic advantage, but a set of financial institutions that have served the world well could be undermined.</div></span>
#                                               -------------
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">“If you don’t change the economic fundamentals, intervening in currency markets won’t be effective,” said
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     David Dollar
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , a senior fellow at
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Brookings Institution
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and a former
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Treasury Department
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  representative in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     China
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# . Citing organizations like
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the World Trade Organization
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , he said, “The question for me is, does this end up damaging the core economic institutions?”</div></span>
#                                               -------------
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Nothing about the world economy over
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the last few years
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  has been linear or predictable. There is no reason that the events of
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Aug. 5, 2019
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , need to be the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  chapter of future books about the Global Recession of
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2020
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . But to avoid that result, it matters that world leaders understand just what is at stake — and the pervasive pessimism in markets
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Monday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  was a good indication.</div></span>
#                                               -------------
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Advertisement</div></span>
#                                               -------------

# %%
# TODO: labels count
labels_nyt_dict = {}
for paragraph in nyt_doc:
    for ent in paragraph.ents:
        if spacy.explain(ent.label_) in labels_nyt_dict:
            labels_nyt_dict[spacy.explain(ent.label_)] += 1
        else:
            labels_nyt_dict[spacy.explain(ent.label_)] = 1

# %%
labels_nyt_dict
# Out:
# {'People, including fictional': 9,
#  'Absolute or relative dates or periods': 28,
#  'Percentage, including "%"': 7,
#  'Non-GPE locations, mountain ranges, bodies of water': 2,
#  'Nationalities or religious or political groups': 9,
#  'Countries, cities, states': 18,
#  'Numerals that do not fall under another type': 6,
#  'Monetary values, including unit': 2,
#  'Companies, agencies, institutions, etc.': 12,
#  'Named hurricanes, battles, wars, sports events, etc.': 1,
#  '"first", "second", etc.': 1}

# %%
# TODO: most common items
# The 5 most common items are
sorted(labels_nyt_dict.items(), key = lambda x: x[1], reverse = True)[:5]
# Out:
# [('Absolute or relative dates or periods', 28),
#  ('Countries, cities, states', 18),
#  ('Companies, agencies, institutions, etc.', 12),
#  ('People, including fictional', 9),
#  ('Nationalities or religious or political groups', 9)]

# %%
# TODO: dependencies on a given sentence
nyt_sentences = []
for paragraph in nyt_doc:
    for sentence in paragraph.sents:
        nyt_sentences.append(sentence)
displacy.render(nyt_sentences, style='dep', jupyter = True, minify = True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="0a193a3fe2a3475798e270e2fec96c65-0" class="displacy" width="225" height="137.0" direction="ltr" style="max-width: none; height: 137.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr"><text class="displacy-token" fill="currentColor" text-anchor="middle" y="47.0"><tspan class="displacy-word" fill="currentColor" x="50">Advertisement</tspan><tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan></text></svg><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="0a193a3fe2a3475798e270e2fec96c65-1" class="displacy" width="400" height="224.5" direction="ltr" style="max-width: none; height: 224.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr"><text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5"><tspan class="displacy-word" fill="currentColor" x="50">Supported</tspan><tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan></text><text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5"><tspan class="displacy-word" fill="currentColor" x="225">by</tspan><tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">ADP</tspan></text><g class="displacy-arrow"><path class="displacy-arc" id="arrow-0a193a3fe2a3475798e270e2fec96c65-1-0" stroke-width="2px" d="M70,89.5 C70,2.0 225.0,2.0 225.0,89.5" fill="none" stroke="currentColor"/><text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px"><textPath xlink:href="#arrow-0a193a3fe2a3475798e270e2fec96c65-1-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">agent</textPath></text><path class="displacy-arrowhead" d="M225.0,91.5 L233.0,79.5 217.0,79.5" fill="currentColor"/></g></svg><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="0a193a3fe2a3475798e270e2fec96c65-2" class="displacy" width="2500" height="487.0" direction="ltr" style="max-width: none; height: 487.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr"><text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0"><tspan class="displacy-word" fill="currentColor" x="50">A</tspan><tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan></text><text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0"><tspan class="displacy-word" fill="currentColor" x="225">trade</tspan><tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NOUN</tspan></text><text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0"><tspan class="displacy-word" fill="currentColor" x="400">war</tspan><tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">NOUN</tspan></text><text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0"><tspan class="displacy-word" fill="currentColor" x="575">spills</tspan><tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">VERB</tspan></text><text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0"><tspan class="displacy-word" fill="currentColor" x="750">into</tspan><tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">ADP</tspan></text><text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0"><tspan class="displacy-word" fill="currentColor" x="925">the</tspan><tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">DET</tspan></text><text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0"><tspan class="displacy-word" fill="currentColor" x="1100">realm</tspan><tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">NOUN</tspan></text><text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0"><tspan class="displacy-word" fill="currentColor" x="1275">of</tspan><ts ...

# %%
# TODO: NER on the sentence
displacy.render(nyt_sentences, style='ent', jupyter = True, minify = True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Advertisement</div><div class="entities" style="line-height: 2.5; direction: ltr">Supported by</div><div class="entities" style="line-height: 2.5; direction: ltr">A trade war spills into the realm of currency, with no end in sight.</div><div class="entities" style="line-height: 2.5; direction: ltr">By <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">Neil Irwin<span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span></mark></div><div class="entities" style="line-height: 2.5; direction: ltr">To most people, <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">Aug. 9, 2007<span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span></mark>, was an ordinary enough <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">summer day<span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span></mark>. </div><div class="entities" style="line-height: 2.5; direction: ltr">The stock market fell <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">about 3 percent<span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERCENT</span></mark>, sufficiently notable to lead the major newspapers, but hardly anything that would generate panic in the streets.</div><div class="entities" style="line-height: 2.5; direction: ltr">Yet to many people who work in economic policy or financial markets, <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">that day<span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span></mark> was the beginning of what would eventually be called the global financial crisis. </div><div class="entities" style="line-height: 2.5; direction: ltr">It was <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">the day<span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span></mark> that lending froze up among banks within <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">Europe<span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span></mark>, triggered by the breakdown in the market for bonds backed by <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">American<span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span></mark> home mortgages, and central banks first intervened to try to keep money flowing.</div><div class="entities" style="line-height: 2.5; direction: ltr"><mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">Monday<span style="font-size: 0.8em; font-weight: bold ...

# %% [markdown]
# # 3. Analyse French News with NER

# %%
#Create the nlp object -- this object will parse the text and preprocess it automatically
nlp_fr = spacy.load("fr_core_news_md")

# %%
# parse the document with spacy.load
echos_doc = [nlp_fr(paragraph) for paragraph in text_echos]

# %%
echos_doc
# Out:
# [Deux jugements récents rendus à Valence et à Madrid reconnaissent les livreurs à vélo comme salariés de la plate-forme et lui réclament les cotisations sociales impayées.,
#  Les livreurs à vélos de Deliveroo sont bien des salariés et non pas des travailleurs indépendants. C'est ce qu'a décidé la justice espagnole qui a condamné la plate-forme britannique pour fraude à la Sécurité sociale à deux reprises en l'espace de quelques semaines. Alertés par l'Inspection du travail, des tribunaux régionaux avaient en effet été appelés à se prononcer dans le cadre de deux affaires distinctes sur le statut des cyclistes de l'entreprise de livraison de repas à domicile.,
#  Un premier jugement, rendu à Valence en juin, avait tranché en faveur de l'administration qui dénonçait le cas de 97 coursiers déclarés frauduleusement comme « autonomos », équivalent espagnol du statut d'autoentrepreneur, et réclamait les cotisations sociales impayées par Deliveroo. A Madrid, un mois plus tard, la justice émettait un jugement similaire concernant le cas de 532 livreurs et condamnait là aussi la plate-forme, exigeant le paiement de 1,2 million d'euros de cotisations. Deliveroo devrait aller en appel, en attendant d'autres jugements sur des cas semblables qui devraient être rendus dans les prochains mois, à Barcelone et à Saragosse.,
#  A Valence et à Madrid, les deux décisions de justice ont clairement convergé en considérant que le faux statut d'« autonomo » imposé aux coursiers avait permis à l'entreprise de faire l'économie du paiement des cotisations sociales. Alors que Deliveroo présente les cyclistes comme indépendants, libres de leurs horaires et disposant de leurs propres outils de travail, le tribunal de Valence établit que « les vrais moyens de production ne sont pas le vélo ou le téléphone portable utilisés par le rider, mais la plate-forme digitale permettant de connecter l'offre et la demande, propriété de l'entreprise ». La liberté horaire est par ailleurs relative selon le tribunal puisque les algorithmes peuvent favoriser ou sanctionner un livreur plus ou moins efficace.,
#  Selon les magistrats de Madrid, « une fois la commande acceptée », le coursier doit « l'honorer en suivant les instructions détaillées déterminées par l'entreprise, sans marge appréciable d'autonomie ». Le jugement donne pour preuve le modus operandi de la plate-forme qui fait accompagner les livreurs novices lors de leur première tournée par des coursiers plus expérimentés pour leur « enseigner la mécanique du service ».,
#  Ces sentences ont eu lieu peu de temps après la mort, à Barcelone, d'un livreur à vélo de l'entreprise Glovo, qui opère dans les conditions comparables à celles de Deliveroo. Son décès en mai dernier dans un accident de la circulation, avait attiré l'attention de l'opinion publique sur la précarité du travail des coursiers. Il avait permis de mettre à jour la façon dont Glovo, comme Deliveroo et les autres plates-formes, sont utilisées depuis des années par des migrants sans papiers pour pouvoir décrocher quelques heures de travail, et comment les cyclistes sont poussés à accélérer la cadence et à prendre des risques lors de leurs déplacements, mis sous pression par les systèmes de notation des clients et des algorithmes, afin d'avoir plus de travail et aux heures les plus rentables.,
#  Cécile Thibaud  (Correspondante à Madrid),
#  Chaque jour, la rédaction des Echos répond à votre besoin d’une information fiable et vous aide à prendre les meilleures décisions.,
#  Conservez une vision globale de la situation, en France et dans le monde. Décryptez les conséquences de la crise sur l’économie, les entreprises et les marchés. Eclairez votre réflexion avec des points de vue, des idées et des contributions de tous horizons.,
#  Reprenez un temps d’avance avec Les Echos. Abonnez-vous dès maintenant !,
#  ,
#  ,
#  Tous droits réservés - Les Echos 2020]

# %%
# TODO: load entities
for paragraph in echos_doc:
    spacy.displacy.render(paragraph, style="ent")
    print('                                              -------------                                          ')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Deux jugements récents rendus à
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Valence
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  et à
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Madrid
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  reconnaissent les livreurs à vélo comme salariés de la plate-forme et lui réclament les cotisations sociales impayées.</div></span>
#                                               -------------
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Les livreurs à vélos de
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Deliveroo
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  sont bien des salariés et non pas des travailleurs indépendants. C'est ce qu'a décidé la justice espagnole qui a condamné la plate-forme britannique pour fraude à la
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sécurité sociale
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  à deux reprises en l'espace de quelques semaines. Alertés par l'
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Inspection du travail
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , des tribunaux régionaux avaient en effet été appelés à se prononcer dans le cadre de deux affaires distinctes sur le statut des cyclistes de l'entreprise de livraison de repas à domicile.</div></span>
#                                               -------------
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Un premier jugement, rendu à
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Valence
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  en juin, avait tranché en faveur de l'administration qui dénonçait le cas de 97 coursiers déclarés frauduleusement comme « autonomos », équivalent espagnol du statut d'autoentrepreneur, et réclamait les cotisations sociales impayées par
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Deliveroo
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# . A
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Madrid
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# , un mois plus tard, la justice émettait un jugement similaire concernant le cas de 532 livreurs et condamnait là aussi la plate-forme, exigeant le paiement de 1,2 million d'euros de cotisations.
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Deliveroo
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  devrait aller en appel, en attendant d'autres jugements sur des cas semblables qui devraient être rendus dans les prochains mois, à
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Barcelone
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  et à
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Saragosse
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# .</div></span>
#                                               -------------
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">A
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Valence
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  et à
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Madrid
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# , les deux décisions de justice ont clairement convergé en considérant que le faux statut d'« autonomo » imposé aux coursiers avait permis à l'entreprise de faire l'économie du paiement des cotisations sociales. Alors que
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Deliveroo
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  présente les cyclistes comme indépendants, libres de leurs horaires et disposant de leurs propres outils de travail, le
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     tribunal de Valence
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  établit que « les vrais moyens de production ne sont pas le vélo ou le téléphone portable utilisés par le rider, mais la plate-forme digitale permettant de connecter l'offre et la demande, propriété de l'entreprise ». La liberté horaire est par ailleurs relative selon le tribunal puisque les algorithmes peuvent favoriser ou sanctionner un livreur plus ou moins efficace.</div></span>
#                                               -------------
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Selon les magistrats de
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Madrid
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# , « une fois la commande acceptée », le coursier doit « l'honorer en suivant les instructions détaillées déterminées par l'entreprise, sans marge appréciable d'autonomie ». Le jugement donne pour preuve le modus operandi de la plate-forme qui fait accompagner les livreurs novices lors de leur première tournée par des coursiers plus expérimentés pour leur « enseigner la mécanique du service ».</div></span>
#                                               -------------
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Ces sentences ont eu lieu peu de temps après la mort, à
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Barcelone
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# , d'un livreur à vélo de l'entreprise
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Glovo
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , qui opère dans les conditions comparables à celles de
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Deliveroo
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# . Son décès en mai dernier dans un accident de la circulation, avait attiré l'attention de l'opinion publique sur la précarité du travail des coursiers. Il avait permis de mettre à jour la façon dont
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Glovo
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# , comme
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Deliveroo
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  et les autres plates-formes, sont utilisées depuis des années par des migrants sans papiers pour pouvoir décrocher quelques heures de travail, et comment les cyclistes sont poussés à accélérer la cadence et à prendre des risques lors de leurs déplacements, mis sous pression par les systèmes de notation des clients et des algorithmes, afin d'avoir plus de travail et aux heures les plus rentables.</div></span>
#                                               -------------
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Cécile Thibaud
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# (
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Correspondante
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  à
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Madrid
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# )</div></span>
#                                               -------------
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Chaque jour, la rédaction des
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Echos
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  répond à votre besoin d’une information fiable et vous aide à prendre les meilleures décisions.</div></span>
#                                               -------------
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Conservez une vision globale de la situation, en
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     France
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  et dans le monde. Décryptez les conséquences de la crise sur l’économie, les entreprises et les marchés.
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Eclairez
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  votre réflexion avec des points de vue, des idées et des contributions de tous horizons.</div></span>
#                                               -------------
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Reprenez un temps d’avance avec
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Les Echos
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# .
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Abonnez
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# -vous dès maintenant !</div></span>
#                                               -------------
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr"></div></span>
#                                               -------------
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr"></div></span>
#                                               -------------
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Tous droits réservés - Les Echos 2020</div></span>
#                                               -------------

# %%
# TODO: labels count
labels_echos_dict = {}
for paragraph in echos_doc:
    for ent in paragraph.ents:
        if spacy.explain(ent.label_) in labels_echos_dict:
            labels_echos_dict[spacy.explain(ent.label_)] += 1
        else:
            labels_echos_dict[spacy.explain(ent.label_)] = 1

# %%
labels_echos_dict
# Out:
# {'Non-GPE locations, mountain ranges, bodies of water': 14,
#  'Companies, agencies, institutions, etc.': 12,
#  'Miscellaneous entities, e.g. events, nationalities, products or works of art': 1,
#  'Named person or family.': 2}

# %%
# TODO: most common items
# The 5 most common items are
sorted(labels_echos_dict.items(), key = lambda x: x[1], reverse = True)[:5]
# Out:
# [('Non-GPE locations, mountain ranges, bodies of water', 14),
#  ('Companies, agencies, institutions, etc.', 12),
#  ('Named person or family.', 2),
#  ('Miscellaneous entities, e.g. events, nationalities, products or works of art',
#   1)]

# %%
# TODO: dependencies on a given sentence
echos_sentences = []
for paragraph in echos_doc:
    for sentence in paragraph.sents:
        echos_sentences.append(sentence)
displacy.render(echos_sentences, style='dep', jupyter = True, minify = True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="fr" id="8956bd4be0b34ca18f5d67f0b3761624-0" class="displacy" width="4775" height="662.0" direction="ltr" style="max-width: none; height: 662.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr"><text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0"><tspan class="displacy-word" fill="currentColor" x="50">Deux</tspan><tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NUM</tspan></text><text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0"><tspan class="displacy-word" fill="currentColor" x="225">jugements</tspan><tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NOUN</tspan></text><text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0"><tspan class="displacy-word" fill="currentColor" x="400">récents</tspan><tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">ADJ</tspan></text><text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0"><tspan class="displacy-word" fill="currentColor" x="575">rendus</tspan><tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">VERB</tspan></text><text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0"><tspan class="displacy-word" fill="currentColor" x="750">à</tspan><tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">ADP</tspan></text><text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0"><tspan class="displacy-word" fill="currentColor" x="925">Valence</tspan><tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">PROPN</tspan></text><text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0"><tspan class="displacy-word" fill="currentColor" x="1100">et</tspan><tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">CCONJ</tspan></text><text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0"><tspan class="displacy-word" fill="currentColor" x="1275">à</tspan><tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">ADP</tspan></text><text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0"><tspan class="displacy-word" fill="currentColor" x="1450">Madrid</tspan><tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">PROPN</tspan></text><text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0"><tspan class="displacy-word" fill="currentColor" x="1625">reconnaissent</tspan><tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">VERB</tspan></text><text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0"><tspan class="displacy-word" fill="currentColor" x="1800">les</tspan><tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">DET</tspan></text><text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0"><tspan class="displacy-word" fill="currentColor" x="1975">livreurs</tspan><tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">NOUN</tspan></text><text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0"><tspan class="displacy-word" fill="currentColor" x="2150">à</tspan><tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">ADP</tspan></text><text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0"><tspan class="displacy-word" fill="currentColor" x="2325">vélo</tspan><tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">NOUN</tspan></text><text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0"><tspan class="displacy-word" fill="currentColor" x="2500">comme</tspan><tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">ADP</tspan></text><text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0"><tspan class="displacy-word" fill="currentColor" x="267 ...

# %%
# TODO: NER on the sentence
displacy.render(echos_sentences, style='ent', jupyter = True, minify = True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Deux jugements récents rendus à <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">Valence<span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span></mark> et à <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">Madrid<span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span></mark> reconnaissent les livreurs à vélo comme salariés de la plate-forme et lui réclament les cotisations sociales impayées.</div><div class="entities" style="line-height: 2.5; direction: ltr">Les livreurs à vélos de <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">Deliveroo<span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span></mark> sont bien des salariés et non pas des travailleurs indépendants. </div><div class="entities" style="line-height: 2.5; direction: ltr">C'est ce qu'a décidé la justice espagnole qui a condamné la plate-forme britannique pour fraude à la <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">Sécurité sociale<span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span></mark> à deux reprises en l'espace de quelques semaines. </div><div class="entities" style="line-height: 2.5; direction: ltr">Alertés par l'<mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">Inspection du travail<span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span></mark>, des tribunaux régionaux avaient en effet été appelés à se prononcer dans le cadre de deux affaires distinctes sur le statut des cyclistes de l'entreprise de livraison de repas à domicile.</div><div class="entities" style="line-height: 2.5; direction: ltr">Un premier jugement, rendu à <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">Valence<span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span></mark> en juin, avait tranché en faveur de l'administration qui dénonçait le cas de 97 coursiers déclarés frauduleusement comme « autonomos », équivalent espagnol du statut d'autoentrepreneur, et réclamait les cotisations sociales impayées par <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">Deliveroo<span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span></mark>. </div><div class="entities" style="line-height: 2.5; direction: ltr">A <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">Madrid<span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span></mark>, un mois plus tard, la justice émettait un jugement similaire concernant le cas de 532 livreurs et condamnait là aussi la plate-forme, exigeant  ...
